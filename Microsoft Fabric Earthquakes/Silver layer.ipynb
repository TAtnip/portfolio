# %% [markdown]
# # Worldwide Earthquake Events API - Silver Layer Processing

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType

from datetime import date, timedelta
# Out:
# StatementMeta(, 7238cbb9-6eaa-49ed-ae3d-f2e6e7e5d088, 10, Finished, Available, Finished)

# %%
## Read in the raw data from the bronze layer
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 7238cbb9-6eaa-49ed-ae3d-f2e6e7e5d088, 12, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 8aaf19ac-cdf8-4f7f-9843-07b0b01570d1)

# %%
## Begin cleaning the data retrieved in the bronze layer
df = (df.select(
    'id',
    col('geometry.coordinates').getItem(0).alias('longitude'),
    col('geometry.coordinates').getItem(1).alias('latitude'),
    col('geometry.coordinates').getItem(2).alias('elevation'),
    col('properties.title').alias('title'),
    col('properties.place').alias('place_description'),
    col('properties.sig').alias('sig'),
    col('properties.mag').alias('mag'),
    col('properties.magType').alias('magType'),
    col('properties.time').alias('time'),
    col('properties.updated').alias('updated')
    ))
# Out:
# StatementMeta(, 7238cbb9-6eaa-49ed-ae3d-f2e6e7e5d088, 13, Finished, Available, Finished)

# %%
df = (df
    .withColumn('time', col('time')/1000)
    .withColumn('updated', col('updated')/1000)
    .withColumn('time', col('time').cast(TimestampType()))
    .withColumn('updated', col('updated').cast(TimestampType()))
)
# Out:
# StatementMeta(, 7238cbb9-6eaa-49ed-ae3d-f2e6e7e5d088, 16, Finished, Available, Finished)

# %%
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 7238cbb9-6eaa-49ed-ae3d-f2e6e7e5d088, 18, Finished, Available, Finished)
